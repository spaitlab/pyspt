# %% [markdown]
# # **<font size=4 color=#BB3D00 face=微软雅黑>对数据去趋势</font>**
# 测量的信号可能显示数据中非固有的整体模式，这些趋势有时会妨碍数据分析，因此必须进行去趋势。

# %% [markdown]
# ## **<font size=3  face=微软雅黑>※Matlab案例</font>**

# %% [markdown]
# 网址：https://ww2.mathworks.cn/help/signal/ug/remove-trends-from-data.html
# 描述：本案例由1个示例构成。
# ### - <font color=DarkOrChid size=3>示例1：以具有不同趋势的两种心电图 (ECG) 信号为例，对去趋势进行演示</font>

# %% [markdown]
# ## **<font size=3 face=微软雅黑>※Python案例</font>**

# %% [markdown]
# 针对以上案例，采用Python语言实现。

# %% [markdown]
# ### - <font color=DarkOrChid size=3>示例1：以具有不同趋势的两种心电图 (ECG) 信号为例，对去趋势进行演示</font>

# %%
# !wget https://github.com/spaitlab/pyspt/blob/816ef68d57e86b1478c00a1f9d05d1fba357b886/2-%E4%BF%A1%E5%8F%B7%E7%94%9F%E6%88%90%E5%92%8C%E9%A2%84%E5%A4%84%E7%90%86/2-1-%E5%B9%B3%E6%BB%91%E5%92%8C%E5%8E%BB%E5%99%AA/2-1-2-%E5%AF%B9%E6%95%B0%E6%8D%AE%E5%8E%BB%E8%B6%8B%E5%8A%BF/ecgl.mat?raw=true
# Out:
# 'wget' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !ls
# Out:
# 'ls' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !mv ecgl.mat\?raw\=true ecgl.mat
# Out:
# 'mv' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !wget https://github.com/spaitlab/pyspt/blob/816ef68d57e86b1478c00a1f9d05d1fba357b886/2-%E4%BF%A1%E5%8F%B7%E7%94%9F%E6%88%90%E5%92%8C%E9%A2%84%E5%A4%84%E7%90%86/2-1-%E5%B9%B3%E6%BB%91%E5%92%8C%E5%8E%BB%E5%99%AA/2-1-2-%E5%AF%B9%E6%95%B0%E6%8D%AE%E5%8E%BB%E8%B6%8B%E5%8A%BF/ecgnl.mat?raw=true
# Out:
# 'wget' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !ls
# Out:
# 'ls' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# !mv ecgnl.mat\?raw\=true ecgnl.mat
# Out:
# 'mv' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
# 导入原始信号

from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np

ecgl = loadmat("ecgl.mat")
ecgnl = loadmat("ecgnl.mat")

t = len(ecgl['ecgl'])
x = np.linspace(0, t, t)

# 画图
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(ecgl['ecgl'])
fig.suptitle('ECG Signals with Trends')
plt.ylabel('Voltage (mV)')

ax2.plot(ecgnl['ecgnl'])
plt.ylabel('Voltage (mV)')
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %%
# 对两个信号去趋势

from scipy.signal import detrend

dt_ecgl = detrend(ecgl['ecgl'], axis =- 1, type='linear', bp=0, overwrite_data=False)
dt_ecgnl = detrend(ecgnl['ecgnl'], axis =- 1, type='linear', bp=0, overwrite_data=False)

# %%
# 画出去趋势后的信号
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(dt_ecgl)
fig.suptitle('Detrended ECG Signals')
plt.ylabel('Voltage (mV)')

ax2.plot(dt_ecgnl)
plt.ylabel('Voltage (mV)')
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %% [markdown]
# 这些趋势已有效地去除，可以看到与原始信号相比，信号的基线已不再偏移，它们现在可用于进一步处理。
